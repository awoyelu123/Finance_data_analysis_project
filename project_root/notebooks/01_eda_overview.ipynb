# %%
import os, sys
print("CWD:", os.getcwd())
print("Files in .. :", os.listdir(".."))
print("Files in ../src:", os.listdir("../src"))
# Out:
# CWD: c:\Users\awoye\Finance_data_analysis_project\project_root\notebooks
# Files in .. : ['.gitignore', 'credentials.yaml', 'data', 'notebooks', 'README.md', 'src']
# Files in ../src: ['convert_dat_to_csv.py', 'dataframe_info.py', 'data_transform.py', 'db_utils.py', '__init__.py', '__pycache__']

# %%
from src.data_transform import DataTransform
from src.dataframe_info import DataFrameInfo

print(DataTransform)
print(DataFrameInfo)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.data_transform import DataTransform
#       2 from src.dataframe_info import DataFrameInfo
#       4 print(DataTransform)
#
# ModuleNotFoundError: No module named 'src'
